# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers

# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32

#constant
BATCH_SIZE = 128
EPOCHS = 20
CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = tf.keras.optimizers.RMSprop()

#define the convnet 
def build(input_shape, classes):
	model = models.Sequential() 
	model.add(layers.Convolution2D(32, (3, 3), activation='relu',
                        input_shape=input_shape))
	model.add(layers.MaxPooling2D(pool_size=(2, 2)))
	model.add(layers.Dropout(0.25)) 

	model.add(layers.Flatten())
	model.add(layers.Dense(512, activation='relu'))
	model.add(layers.Dropout(0.5))
	model.add(layers.Dense(classes, activation='softmax'))
	return model

# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
# normalize
X_train, X_test = X_train / 255.0, X_test / 255.0
# convert to categorical
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, CLASSES)

model=build((IMG_ROWS, IMG_COLS, IMG_CHANNELS), CLASSES)
model.summary()

# use TensorBoard, princess Aurora!
callbacks = [
  # Write TensorBoard logs to `./logs` directory
  tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

# train
model.compile(loss='categorical_crossentropy', optimizer=OPTIM,
	metrics=['accuracy'])
 
model.fit(X_train, y_train, batch_size=BATCH_SIZE,
	epochs=EPOCHS, validation_split=VALIDATION_SPLIT, 
	verbose=VERBOSE, callbacks=callbacks) 
score = model.evaluate(X_test, y_test,
                     batch_size=BATCH_SIZE, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               3686912
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,692,938
# Trainable params: 3,692,938
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 313/313 [==============================] - 16s 50ms/step - loss: 1.7110 - accuracy: 0.3929 - val_loss: 1.4614 - val_accuracy: 0.4883
# Epoch 2/20
# 313/313 [==============================] - 16s 53ms/step - loss: 1.3901 - accuracy: 0.5113 - val_loss: 1.2676 - val_accuracy: 0.5610
# Epoch 3/20
# 313/313 [==============================] - 15s 48ms/step - loss: 1.2463 - accuracy: 0.5612 - val_loss: 1.2133 - val_accuracy: 0.5765
# Epoch 4/20
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1502 - accuracy: 0.5975 - val_loss: 1.2112 - val_accuracy: 0.5744
# Epoch 5/20
# 313/313 [==============================] - 15s 47ms/step - loss: 1.0775 - accuracy: 0.6219 - val_loss: 1.2093 - val_accuracy: 0.5874
# Epoch 6/20
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0173 - accuracy: 0.6460 - val_loss: 1.1873 - val_accuracy: 0.6001
# Epoch 7/20
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9630 - accuracy: 0.6632 - val_loss: 1.0240 - val_accuracy: 0.6480
# Epoch 8/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.9091 - accuracy: 0.6819 - val_loss: 1.1123 - val_accuracy: 0.6303
# Epoch 9/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.8651 - accuracy: 0.6990 - val_loss: 1.1428 - val_accuracy: 0.6171
# Epoch 10/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.8212 - accuracy: 0.7160 - val_loss: 0.9873 - val_accuracy: 0.6687
# Epoch 11/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.7795 - accuracy: 0.7270 - val_loss: 0.9962 - val_accuracy: 0.6698
# Epoch 12/20
# 313/313 [==============================] - 16s 50ms/step - loss: 0.7453 - accuracy: 0.7429 - val_loss: 1.0052 - val_accuracy: 0.6613
# Epoch 13/20
# 313/313 [==============================] - 16s 52ms/step - loss: 0.7081 - accuracy: 0.7552 - val_loss: 1.0127 - val_accuracy: 0.6720
# Epoch 14/20
# 313/313 [==============================] - 16s 50ms/step - loss: 0.6797 - accuracy: 0.7635 - val_loss: 0.9878 - val_accuracy: 0.6843
# Epoch 15/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.6430 - accuracy: 0.7749 - val_loss: 1.0391 - val_accuracy: 0.6738
# Epoch 16/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.6227 - accuracy: 0.7854 - val_loss: 0.9851 - val_accuracy: 0.6800
# Epoch 17/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.5956 - accuracy: 0.7963 - val_loss: 1.0418 - val_accuracy: 0.6699
# Epoch 18/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.5697 - accuracy: 0.8048 - val_loss: 1.0188 - val_accuracy: 0.6780
# Epoch 19/20
# 313/313 [==============================] - 15s 47ms/step - loss: 0.5516 - accuracy: 0.8147 - val_loss: 1.0486 - val_accuracy: 0.6815
# Epoch 20/20
# 313/313 [==============================] - 15s 48ms/step - loss: 0.5379 - accuracy: 0.8156 - val_loss: 1.0344 - val_accuracy: 0.6717
# 79/79 [==============================] - 1s 9ms/step - loss: 1.0270 - accuracy: 0.6663
#
# Test score: 1.0269607305526733
# Test accuracy: 0.6662999987602234

# %%
from skimage.transform import resize
from imageio import imread
from tensorflow.keras.optimizers import SGD

img_names = ["cat-standing.jpg", "dog.jpg"]
imgs = [resize(imread(img_name), (32, 32)).astype("float32") for img_name in img_names]
imgs = np.array(imgs) / 255
print("imgs.shape:", imgs.shape)

predictions = model.predict(imgs)
print("predictions:", predictions)
# Out:
# imgs.shape: (2, 32, 32, 3)
# predictions: [[3.5897791e-01 1.6177188e-03 4.4537893e-01 1.4154789e-01 1.1080014e-02
#   3.5847610e-04 4.5002872e-04 6.1721000e-04 3.9948996e-02 2.2788505e-05]
#  [3.5497630e-01 1.6468030e-03 4.5311496e-01 1.3686101e-01 1.1408463e-02
#   3.5878952e-04 4.8456751e-04 6.0917425e-04 4.0517263e-02 2.2633880e-05]]
